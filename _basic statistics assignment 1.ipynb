# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %%
df=pd.read_csv("sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
#BASIC EXPLANATION

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
#VISUALIZATION
#BARPLOT

# %%
plt.figure(figsize=(10,6))
df['Volume'].plot(kind='bar')
plt.title("BAR PLOT OF THE VOLUME")
plt.xlabel("VOLUME")
plt.ylabel("VALUES")
plt.show()

# %%
# BaXPLOT FOR AVG PRICE

# %%
plt.figure(figsize=(10,6))
df["Avg Price"].plot(kind="bar")
plt.title("bar plot of avg price")
plt.xlabel("avg price")
plt.ylabel("values")
plt.show()

# %%
plt.figure(figsize=(20,9))
df['Total Sales Value'].plot(kind='bar')
plt.title("bar plot of the total sales value")
plt.xlabel("total sales value")
plt.ylabel('values')
plt.show()

# %%
plt.figure(figsize=(20,6))
df['Discount Rate (%)'].plot(kind='bar')
plt.title('bar plot of the discount rate (%)')
plt.xlabel("discount rate ")
plt.ylabel("values")
plt.show()

# %%
plt.figure(figsize=(20,5))
df['Discount Amount'].plot(kind='bar')
plt.title("bar plot of the discount anount")
plt.xlabel("discount amount")
plt.ylabel("values")
plt.show()

# %%
plt.figure(figsize=(20,10))
df['Net Sales Value'].plot(kind='bar')
plt.title("bar plot of the net sales value")
plt.xlabel("net sales value")
plt.ylabel("values")
plt.show()

# %%
#BOX PLOT

# %%
plt.figure(figsize=(20,10))
df['Volume'].plot(kind='box')
plt.title('box plot of the volume')
# Out:
# Text(0.5, 1.0, 'box plot of the volume')

# %%
plt.figure(figsize=(20,10))
df["Avg Price"].plot(kind='box')
plt.title("box plot of the avg price")
plt.show()

# %%
plt.figure(figsize=(20,10))
df['Total Sales Value'].plot(kind='box')
plt.title('box plot of the total sales value')
plt.show()

# %%
plt.figure(figsize=(20,10))
df['Discount Rate (%)'].plot(kind='box')
plt.title("box plot of the discount rate")
plt.show()

# %%
plt.figure(figsize=(20,10))
df['Discount Amount'].plot(kind='box')
plt.title("box plot discount amount ")
plt.show()

# %%
plt.figure(figsize=(20,10))
df["Net Sales Value"].plot(kind='box')
plt.title('box plot of the net sales value')
plt.show()

# %%
#histogram

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Volume'],kde=True,bins=10)
plt.title("histogram of the avg price")
plt.xlabel("avg price")
plt.ylabel("frequency")
df['Volume'].skew()
# Out:
# 2.731723626557714

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Avg Price'],kde=True,bins=10)
plt.title("histogram of avg price")
plt.xlabel("avg price")
plt.ylabel("frequency")
plt.show()

# %%
df['Avg Price'].skew()
# Out:
# 1.9088730767759727

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Total Sales Value'],kde=True,bins=10)
plt.title("histogram of total sales price")
plt.xlabel("total sales price")
plt.ylabel("frequency")
plt.show()

# %%
df['Total Sales Value'].skew()
# Out:
# 1.5347293238977937

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Discount Rate (%)'],kde=True ,bins=10)
plt.title('histogram of discount rate ')
plt.xlabel("discount rate")
plt.ylabel("frequency")
plt.show()

# %%
df['Discount Rate (%)'].skew()
# Out:
# -1.0622943696988825

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Discount Amount'],kde=True,bins=10)
plt.title("histogram of the discount amount")
plt.xlabel("discount amount")
plt.ylabel("frequency")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Net Sales Value'],kde=True ,bins=10)
plt.title("histogram of the net sales value")
plt.xlabel("net sales value")
plt.ylabel("frequency")
plt.show()

# %%
df["Net Sales Value"].skew()
# Out:
# 1.5408217575344376
